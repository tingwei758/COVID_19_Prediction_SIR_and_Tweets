# %%
import numpy as np
import pandas as pd
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("covid19.csv")
data.head()
# Out:
#    pruid   prname prnameFR        date  numconf  numprob  numdeaths  numtotal  \
# 0     48  Alberta  Alberta  08-03-2020        1        0        0.0         1
# 1     48  Alberta  Alberta  09-03-2020        7        0        0.0         7
# 2     48  Alberta  Alberta  11-03-2020       14        0        0.0        14
# 3     48  Alberta  Alberta  12-03-2020       19        0        0.0        19
# 4     48  Alberta  Alberta  13-03-2020       23        0        0.0        23
#
#    numtested  numrecover  percentrecover  ratetested  numtoday  percentoday
# 0        NaN         NaN             NaN         NaN       1.0        1.000
# 1        NaN         NaN             NaN         NaN       6.0        6.000
# 2     1969.0         NaN             NaN         NaN       7.0        1.000
# 3     4109.0         NaN             NaN         NaN       5.0        0.357
# 4     4109.0         NaN             NaN         NaN       4.0        0.211

# %%
datafilter = data.prname == "Canada"
canadadata = data[datafilter]
canadadata
# Out:
#      pruid  prname prnameFR        date  numconf  numprob  numdeaths  \
# 98       1  Canada   Canada  31-01-2020        4        0        0.0
# 99       1  Canada   Canada  08-02-2020        7        0        0.0
# 100      1  Canada   Canada  16-02-2020        8        0        0.0
# 101      1  Canada   Canada  21-02-2020        9        0        0.0
# 102      1  Canada   Canada  24-02-2020       10        0        0.0
# 103      1  Canada   Canada  25-02-2020       11        0        0.0
# 104      1  Canada   Canada  26-02-2020       12        0        0.0
# 105      1  Canada   Canada  27-02-2020       13        0        0.0
# 106      1  Canada   Canada  29-02-2020       15        0        0.0
# 107      1  Canada   Canada  01-03-2020       24        0        0.0
# 108      1  Canada   Canada  03-03-2020       33        0        0.0
# 109      1  Canada   Canada  04-03-2021       39        0        0.0
# 110      1  Canada   Canada  05-03-2020       45        0        0.0
# 111      1  Canada   Canada  06-03-2020       51        0        0.0
# 112      1  Canada   Canada  07-03-2020       57        0        0.0
# 113      1  Canada   Canada  08-03-2020       62        0        0.0
# 114      1  Canada   Canada  09-03-2020       77        0        0.0
# 115      1  Canada   Canada  10-03-2021       90        0        0.0
# 116      1  Canada   Canada  11-03-2020      103        0        0.0
# 117      1  Canada   Canada  12-03-2020      138        3        0.0
# 118      1  Canada   Canada  13-03-2020      176        3        0.0
# 119      1  Canada   Canada  14-03-2020      193        6        0.0
# 120      1  Canada   Canada  15-03-2020      249        4        0.0
# 121      1  Canada   Canada  16-03-2020      324       17        0.0
# 122      1  Canada   Canada  17-03-2020      424       16        0.0
# 123      1  Canada   Canada  18-03-2020      569       28        0.0
# 124      1  Canada   Canada  19-03-2020      846       27        0.0
# 125      1  Canada   Canada  20-03-2020      971       33       12.0
# 126      1  Canada   Canada  21-03-2020     1302       69       18.0
# 127      1  Canada   Canada  22-03-2020     1430       41       20.0
# 128      1  Canada   Canada  23-03-2020     1646      445       24.0
# 129      1  Canada   Canada  24-03-2020     1959      833       27.0
# 130      1  Canada   Canada  25-03-2020     3385       24       35.0
# 131      1  Canada   Canada  26-03-2020     4018       25       39.0
# 132      1  Canada   Canada  27-03-2020     4675       14       53.0
# 133      1  Canada   Canada  28-03-2020     5386       39       59.0
# 134      1  Canada   Canada  29-03-2020     6255        3       61.0
# 135      1  Canada   Canada  30-03-2020     7424       13       89.0
# 136      1  Canada   Canada  31-03-2020     8536       12       96.0
# 137      1  Canada   Canada  01-04-2020     9595       18      109.0
# 138      1  Canada   Canada  02-04-2020    11268       15      138.0
# 139      1  Canada   Canada  03-04-2020    12519       18      187.0
# 140      1  Canada   Canada  04-04-2020    13882       22      231.0
# 141      1  Canada   Canada  05-04-2020    15496       16      280.0
# 142      1  Canada   Canada  06-04-2020    16653       14      323.0
# 143      1  Canada   Canada  07-04-2020    17883       14      380.0
# 144      1  Canada   Canada  08-04-2020    19274       15      435.0
# 145      1  Canada   Canada  09-04-2020    20748       17      509.0
# 146      1  Canada   Canada  10-04-2020    22133       15      569.0
# 147      1  Canada   Canada  11-04-2020    23301       17      653.0
# 148      1  Canada   Canada  12-04-2020    24365       18      717.0
# 149      1  Canada   Canada  13-04-2020    25663       17      780.0
# 150      1  Canada   Canada  14-04-2020    27046       17      903.0
# 151      1  Canada   Canada  15-04-2020    28364       17     1010.0
# 152      1  Canada   Canada  16-04-2020    30081       11     1193.0
# 153      1  Canada   Canada  17-04-2020    31872       12     1309.0
# 154      1  Canada   Canada  18-04-2020    33341       13     1467.0
# 155      1  Canada   Canada  19-04-2020    33909       13     1506.0
#
#      numtotal  numtested  numrecover  percentrecover  ratetested  numtoday  \
# 98          4        NaN         NaN             NaN         NaN       4.0
# 99          7        NaN         NaN             NaN         NaN       3.0
# 100         8        NaN         NaN             NaN         NaN       1.0
# 101         9        NaN         NaN             NaN         NaN       1.0
# 102        10        NaN         NaN             NaN         NaN       1.0
# 103        11        NaN         NaN             NaN         NaN       1.0
# 104        12        NaN         NaN             NaN         NaN       1.0
# 105        13        NaN         NaN             NaN         NaN       1.0
# 106        15        NaN         NaN             NaN         NaN       2.0
# 107        24        NaN         NaN             NaN         NaN       9.0
# 108        33        NaN         NaN             NaN         NaN       9.0
# 109        39        NaN         NaN             NaN         NaN       6.0
# 110        45        NaN         NaN             NaN         NaN       6.0
# 111        51        NaN         NaN             NaN         NaN       6.0
# 112        57        NaN         NaN             NaN         NaN       6.0
# 113        62        NaN         NaN             NaN         NaN       5.0
# 114        77        NaN         NaN             NaN         NaN      15.0
# 115        90        NaN         NaN             NaN         NaN      13.0
# 116       103    11023.0         NaN             NaN         NaN      13.0
# 117       141    15185.0         NaN             NaN         NaN      38.0
# 118       179    15185.0         NaN             NaN         NaN      38.0
# 119       199    22409.0         NaN             NaN         NaN      20.0
# 120       253    24977.0         NaN             NaN         NaN      54.0
# 121       341    37730.0         NaN             NaN         NaN      88.0
# 122       440    44176.0         NaN             NaN         NaN      99.0
# 123       597    53546.0         NaN             NaN         NaN     157.0
# 124       873    65851.0         NaN             NaN         NaN     276.0
# 125      1004    76814.0         NaN             NaN         NaN     131.0
# 126      1371    88883.0         NaN             NaN         NaN     367.0
# 127      1471    98824.0         NaN             NaN         NaN     100.0
# 128      2091   107147.0         NaN             NaN         NaN     620.0
# 129      2792   125062.0         NaN             NaN         NaN     701.0
# 130      3409   147789.0         NaN             NaN         NaN     617.0
# 131      4043   161603.0         NaN             NaN         NaN     634.0
# 132      4689   170644.0         NaN             NaN         NaN     646.0
# 133      5425   187448.0         NaN             NaN         NaN     736.0
# 134      6258   210435.0         NaN             NaN         NaN     833.0
# 135      7437   225705.0         NaN             NaN         NaN    1179.0
# 136      8548   241138.0         NaN             NaN         NaN    1111.0
# 137      9613   256933.0         NaN             NaN         NaN    1065.0
# 138     11283   273666.0         NaN             NaN         NaN    1670.0
# 139     12537   295065.0         NaN             NaN         NaN    1254.0
# 140     13904   311971.0         NaN             NaN         NaN    1367.0
# 141     15512   324791.0      2335.0           15.05         NaN    1608.0
# 142     16667   336806.0      3616.0           21.70         NaN    1155.0
# 143     17897   348105.0         NaN             NaN         NaN    1230.0
# 144     19289   361969.0         NaN             NaN         NaN    1392.0
# 145     20765   375302.0         NaN             NaN         NaN    1476.0
# 146     22148   391375.0         NaN             NaN         NaN    1383.0
# 147     23318   404651.0         NaN             NaN         NaN    1170.0
# 148     24383   422200.0         NaN             NaN         NaN    1065.0
# 149     25680   437475.0         NaN             NaN         NaN    1297.0
# 150     27063   454983.0         NaN             NaN         NaN    1383.0
# 151     28381   467736.0         NaN             NaN         NaN    1318.0
# 152     30092   487625.0         NaN             NaN         NaN    1711.0
# 153     31884   507701.0         NaN             NaN         NaN    1792.0
# 154     33354   528057.0     11178.0           33.51         NaN       NaN
# 155     33922   536062.0     11520.0           33.96         NaN       NaN
#
#      percentoday
# 98         4.000
# 99         0.750
# 100        0.143
# 101        0.125
# 102        0.111
# 103        0.100
# 104        0.091
# 105        0.083
# 106        0.154
# 107        0.600
# 108        0.375
# 109          NaN
# 110        0.364
# 111        0.133
# 112        0.118
# 113        0.088
# 114        0.242
# 115          NaN
# 116        0.338
# 117        0.369
# 118        0.270
# 119        0.112
# 120        0.271
# 121        0.348
# 122        0.290
# 123        0.357
# 124        0.462
# 125        0.150
# 126        0.366
# 127        0.073
# 128        0.421
# 129        0.335
# 130        0.221
# 131        0.186
# 132        0.160
# 133        0.157
# 134        0.154
# 135        0.188
# 136        0.149
# 137        0.125
# 138        0.174
# 139        0.111
# 140        0.109
# 141        0.116
# 142        0.074
# 143        0.074
# 144        0.078
# 145        0.077
# 146        0.067
# 147        0.053
# 148        0.046
# 149        0.053
# 150        0.054
# 151        0.049
# 152        0.060
# 153        0.060
# 154          NaN
# 155          NaN

# %%
x = canadadata["date"][11:40]
y = canadadata["numconf"][11:40]
y1 = canadadata["numtoday"][11:40]

plt.plot(x, y, 'b-') #blue line is cumulative line
plt.plot(x, y1, 'r-') #red line is new case line

# %%
y2 = canadadata["numdeaths"][11:40]
plt.plot(x, y2, 'r-') #graph of death number

# %%
rate = y2/y
plt.plot(x, rate, 'g-') #graph of death rate

# %%
data2 = pd.read_csv("word_count_pivot.csv")

# %%
words = ["battl",
"case_death",
"coronaviru_lockdown",
"covid_lockdown",
"covid_patient",
"death",
"donat",
"equip",
"hero",
"lockdown",
"new_york",
"nurs",
"polic",
"ppe",
"stayhom",
"stayhomesavel",
"staysaf",
"total",
"ventil",
"york"]

for word in words:
    k = data2[word]
    plt.plot(x, k)
